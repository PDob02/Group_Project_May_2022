# %%
# Initial imports
import pandas as pd
from config import db_password
from sqlalchemy import create_engine

# %%
# Import file
# https://www.kaggle.com/datasets/fmejia21/demographics-of-academy-awards-oscars-winners
file_path = 'Oscars_demographics.csv'
demo_df = pd.read_csv(file_path, encoding="ISO-8859-1")

# %%
demo_df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  670454353    False   finalized                   3      2/10/15 3:45
# 1  670454354    False   finalized                   3      2/10/15 2:03
# 2  670454355    False   finalized                   3      2/10/15 2:05
# 3  670454356    False   finalized                   3      2/10/15 2:04
# 4  670454357    False   finalized                   3      2/10/15 1:48
#
#            birthplace  birthplace:confidence date_of_birth  \
# 0   Chisinau, Moldova                    1.0   30-Sep-1895
# 1   Glasgow, Scotland                    1.0    2-Feb-1886
# 2   Chisinau, Moldova                    1.0   30-Sep-1895
# 3         Chicago, Il                    1.0   23-Feb-1899
# 4  Salt Lake City, Ut                    1.0   23-Apr-1894
#
#    date_of_birth:confidence race_ethnicity  ...          award  \
# 0                       1.0          White  ...  Best Director
# ...

# %%
# Clean demographic dataset
demo_df = demo_df.drop(columns=["_unit_id", "_golden", "_unit_state", "_trusted_judgments", "_last_judgment_at", "race_ethnicity:confidence", "religion", "religion:confidence", "sexual_orientation", "sexual_orientation:confidence", "year_of_award", "year_of_award:confidence", "birthplace:confidence", "date_of_birth:confidence", "award", "race_ethnicity", "biourl", "birthplace_gold", "date_of_birth_gold", "movie", "race_ethnicity_gold", "religion_gold", "religion_gold", "sexual_orientation_gold", "year_of_award_gold"], axis=1)

# %%
# Rearrange column order
demo_df = demo_df[["person", "birthplace", "date_of_birth"]]

# %%
demo_df.head()
# Out:
#             person          birthplace date_of_birth
# 0  Lewis Milestone   Chisinau, Moldova   30-Sep-1895
# 1      Frank Lloyd   Glasgow, Scotland    2-Feb-1886
# 2  Lewis Milestone   Chisinau, Moldova   30-Sep-1895
# 3    Norman Taurog         Chicago, Il   23-Feb-1899
# 4    Frank Borzage  Salt Lake City, Ut   23-Apr-1894

# %%
demo_df.dtypes
# Out:
# person           object
# birthplace       object
# date_of_birth    object
# dtype: object

# %%
demo_df['date_of_birth'] = pd.to_datetime(demo_df['date_of_birth'], errors='coerce')

# %%
demo_df.head()
# Out:
#             person          birthplace date_of_birth
# 0  Lewis Milestone   Chisinau, Moldova    1895-09-30
# 1      Frank Lloyd   Glasgow, Scotland    1886-02-02
# 2  Lewis Milestone   Chisinau, Moldova    1895-09-30
# 3    Norman Taurog         Chicago, Il    1899-02-23
# 4    Frank Borzage  Salt Lake City, Ut    1894-04-23

# %%
demo_df.dtypes
# Out:
# person                   object
# birthplace               object
# date_of_birth    datetime64[ns]
# dtype: object

# %%
# Connection string to PostgreSQL
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/group_project"

# %%
# Create database engine
engine = create_engine(db_string)

# %%
# Export actor demoraphics (demo_df) to a SQL table
demo_df.to_sql(name="actor_demo", con=engine, index=False)
